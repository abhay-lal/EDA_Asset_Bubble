# %%
import pandas as pd 
import numpy as np 
import plotly.express as px

# %%
df=pd.read_csv('data.csv')

# %%
df
# Out:
#     LOCATION     TIME  Unemployment       CPI    P/E     Open     High  \
# 0        USA  1978-01           6.4  6.837607   8.28    93.82    95.15
# 1        USA  1978-02           6.3  6.429780   8.16    89.93    91.32
# 2        USA  1978-03           6.3  6.554622   8.13    87.19    91.35
# 3        USA  1978-04           6.1  6.500000   8.41    88.46    97.91
# 4        USA  1978-05           6.0  6.965174   8.75    97.67   100.32
# ..       ...      ...           ...       ...    ...      ...      ...
# 531      USA  2022-04           3.6       NaN  20.42  4540.32  4593.45
# 532      USA  2022-05           3.6       NaN  19.70  4130.61  4307.66
# 533      USA  2022-06           3.6       NaN  19.77  4149.78  4177.51
# 534      USA  2022-07           3.5       NaN  21.01  3781.08  4140.15
# 535      USA  2022-08           3.7       NaN  19.94  4112.38  4325.28
#
#          Low    Close  Industrial Production  Treasury  Crash  Reason
# ...

# %%
df.drop(['Reason','LOCATION'],axis=1,inplace=True)

# %%
df
# Out:
#         TIME  Unemployment       CPI    P/E     Open     High      Low  \
# 0    1978-01           6.4  6.837607   8.28    93.82    95.15    88.02
# 1    1978-02           6.3  6.429780   8.16    89.93    91.32    86.58
# 2    1978-03           6.3  6.554622   8.13    87.19    91.35    86.45
# 3    1978-04           6.1  6.500000   8.41    88.46    97.91    88.07
# 4    1978-05           6.0  6.965174   8.75    97.67   100.32    94.57
# ..       ...           ...       ...    ...      ...      ...      ...
# 531  2022-04           3.6       NaN  20.42  4540.32  4593.45  4124.28
# 532  2022-05           3.6       NaN  19.70  4130.61  4307.66  3810.32
# 533  2022-06           3.6       NaN  19.77  4149.78  4177.51  3636.87
# 534  2022-07           3.5       NaN  21.01  3781.08  4140.15  3721.56
# 535  2022-08           3.7       NaN  19.94  4112.38  4325.28  3954.53
#
#        Close  Industrial Production  Treasury  Crash
# 0      89.25                47.8693  7.956190      0
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#         TIME  Unemployment       CPI    P/E     Open     High      Low  \
# 0    1978-01           6.4  6.837607   8.28    93.82    95.15    88.02
# 1    1978-02           6.3  6.429780   8.16    89.93    91.32    86.58
# 2    1978-03           6.3  6.554622   8.13    87.19    91.35    86.45
# 3    1978-04           6.1  6.500000   8.41    88.46    97.91    88.07
# 4    1978-05           6.0  6.965174   8.75    97.67   100.32    94.57
# ..       ...           ...       ...    ...      ...      ...      ...
# 523  2021-08           5.2  5.251272  26.23  4406.86  4537.36  4367.73
# 524  2021-09           4.7  5.390349  24.39  4528.80  4545.85  4305.91
# 525  2021-10           4.6  6.221869  24.52  4317.16  4608.08  4278.94
# 526  2021-11           4.2  6.809003  23.63  4610.62  4743.83  4560.00
# 527  2021-12           3.9  7.036403  23.11  4602.82  4808.93  4495.12
#
#        Close  Industrial Production  Treasury  Crash
# 0      89.25                47.8693  7.956190      0
# ...

# %%
fig = go.Figure([go.Scatter(x=df['TIME'], y=df['CPI'])])
fig.show()
# Out:
# <div>                            <div id="ee7a44ab-f045-44b6-aaeb-340e8434d927" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee7a44ab-f045-44b6-aaeb-340e8434d927")) {                    Plotly.newPlot(                        "ee7a44ab-f045-44b6-aaeb-340e8434d927",                        [{"x":["1978-01","1978-02","1978-03","1978-04","1978-05","1978-06","1978-07","1978-08","1978-09","1978-10","1978-11","1978-12","1979-01","1979-02","1979-03","1979-04","1979-05","1979-06","1979-07","1979-08","1979-09","1979-10","1979-11","1979-12","1980-01","1980-02","1980-03","1980-04","1980-05","1980-06","1980-07","1980-08","1980-09","1980-10","1980-11","1980-12","1981-01","1981-02","1981-03","1981-04","1981-05","1981-06","1981-07","1981-08","1981-09","1981-10","
# ...

# %%
fig = go.Figure([go.Scatter(x=df['TIME'], y=df['High'])])
fig.show()
# Out:
# <div>                            <div id="889f33df-3dd5-4c2a-92e0-938eec598598" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("889f33df-3dd5-4c2a-92e0-938eec598598")) {                    Plotly.newPlot(                        "889f33df-3dd5-4c2a-92e0-938eec598598",                        [{"x":["1978-01","1978-02","1978-03","1978-04","1978-05","1978-06","1978-07","1978-08","1978-09","1978-10","1978-11","1978-12","1979-01","1979-02","1979-03","1979-04","1979-05","1979-06","1979-07","1979-08","1979-09","1979-10","1979-11","1979-12","1980-01","1980-02","1980-03","1980-04","1980-05","1980-06","1980-07","1980-08","1980-09","1980-10","1980-11","1980-12","1981-01","1981-02","1981-03","1981-04","1981-05","1981-06","1981-07","1981-08","1981-09","1981-10","
# ...

# %%
fig = go.Figure([go.Scatter(x=df['TIME'], y=df['Industrial Production'])])
fig.show()
# Out:
# <div>                            <div id="928fbd4b-019b-4836-9cd6-dd50cb6121d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("928fbd4b-019b-4836-9cd6-dd50cb6121d3")) {                    Plotly.newPlot(                        "928fbd4b-019b-4836-9cd6-dd50cb6121d3",                        [{"x":["1978-01","1978-02","1978-03","1978-04","1978-05","1978-06","1978-07","1978-08","1978-09","1978-10","1978-11","1978-12","1979-01","1979-02","1979-03","1979-04","1979-05","1979-06","1979-07","1979-08","1979-09","1979-10","1979-11","1979-12","1980-01","1980-02","1980-03","1980-04","1980-05","1980-06","1980-07","1980-08","1980-09","1980-10","1980-11","1980-12","1981-01","1981-02","1981-03","1981-04","1981-05","1981-06","1981-07","1981-08","1981-09","1981-10","
# ...

# %%
sales_mean = df.High.rolling(window=12).mean()
sales_std = df.High.rolling(window=12).std()

# %%
fig, ax = plt.subplots(figsize=(20, 7))
ax.plot(df.High,marker='x', markersize=8, label='High',color='cyan')
ax.plot(sales_mean,marker='o', markersize=4, label='rolling mean', color='red');
ax.plot(sales_std,marker='*', markersize=4, label='rolling std', color='royalblue');
ax.legend()
plt.xlabel('Years')
plt.ylabel('Avg sales')
plt.title('Check of stationarity')
ax.grid(axis='x')

# %%
df.Crash
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 523    0
# 524    0
# 525    0
# 526    0
# 527    0
# Name: Crash, Length: 528, dtype: int64

# %%
fig,ax = plt.subplots(figsize=(15,6))
df.Crash.value_counts().plot(kind='pie',autopct='%1.2f%%',fontsize=12,label='')
plt.show()

# %%
import seaborn as sns
sns.pairplot(df)

# %%
import plotly.graph_objects as go

from datetime import datetime

fig = go.Figure(data=[go.Candlestick(x=df['TIME'],
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])
fig.update_layout(
    title='The Great Mark Crash',
    yaxis_title='S&B 500 Stock',
)

fig.show()
# Out:
# <div>                            <div id="bf34f220-6a3d-4a37-b45d-3f1a41ad0b90" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf34f220-6a3d-4a37-b45d-3f1a41ad0b90")) {                    Plotly.newPlot(                        "bf34f220-6a3d-4a37-b45d-3f1a41ad0b90",                        [{"close":[89.25,87.04,89.21,96.83,97.24,95.53,100.68,103.29,102.54,93.15,94.7,96.11,99.93,96.28,101.5,101.75,99.08,102.91,103.81,109.32,109.32,101.82,106.16,107.94,115.12,113.66,102.09,106.29,111.24,114.24,121.67,122.38,125.46,127.47,140.52,135.76,129.55,131.27,136.0,132.87,132.59,131.21,130.92,122.79,116.18,121.89,126.35,122.55,120.4,113.11,111.96,116.44,111.88,109.61,107.09,119.51,120.42,133.71,138.54,140.64,145.3,148.06,152.96,164.42,162.39,168.11,162.56,164.0
# ...

# %%
df_new=df

# %%
df_new.index=df_new['TIME']
df_new.drop('TIME',axis=1,inplace=True)

# %%
df_new.index=pd.to_datetime(df_new.index, errors='coerce')

# %%
df_new
# Out:
#             Unemployment       CPI    P/E     Open     High      Low    Close  \
# TIME
# 1978-01-01           6.4  6.837607   8.28    93.82    95.15    88.02    89.25
# 1978-02-01           6.3  6.429780   8.16    89.93    91.32    86.58    87.04
# 1978-03-01           6.3  6.554622   8.13    87.19    91.35    86.45    89.21
# 1978-04-01           6.1  6.500000   8.41    88.46    97.91    88.07    96.83
# 1978-05-01           6.0  6.965174   8.75    97.67   100.32    94.57    97.24
# ...                  ...       ...    ...      ...      ...      ...      ...
# 2021-08-01           5.2  5.251272  26.23  4406.86  4537.36  4367.73  4522.68
# 2021-09-01           4.7  5.390349  24.39  4528.80  4545.85  4305.91  4307.54
# 2021-10-01           4.6  6.221869  24.52  4317.16  4608.08  4278.94  4605.38
# 2021-11-01           4.2  6.809003  23.63  4610.62  4743.83  4560.00  4567.00
# 2021-12-01           3.9  7.036403  23.11  4602.82  4808.93  4495.12  4766.18
#
# ...

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf, month_plot, quarter_plot
month_plot(df["High"], ylabel='High');

# %%
quarter_plot(df["High"].resample('Q').sum(), ylabel='High');

# %%
fig = px.line_polar(df_new, r='High', theta=df_new.index, 
                    color=df_new.index.year, line_close=True, 
                    title='Polar seasonal plot',
                    width=600, height=500)
fig.show()
# Out:
# /home/abhaylal/.local/lib/python3.10/site-packages/plotly/express/_core.py:271: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/abhaylal/.local/lib/python3.10/site-packages/plotly/express/_core.py:271: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/abhaylal/.local/lib/python3.10/site-packages/plotly/express/_core.py:271: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/abhaylal/.local/lib/python3.10/site-packages/plotly/express/_core.py:271: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/abhaylal/.local/lib/python3.10/site-packages/plotly/express/_core.py:271: FutureWarning:
#
# ...

# %%
fig, ax = plt.subplots(2)
plot_acf(df['Low'], ax=ax[0])
plot_pacf(df['Low'], ax=ax[1]);
# Out:
# /home/abhaylal/.local/lib/python3.10/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning:
#
# The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.

# %%
# Out:
# /home/abhaylal/.local/lib/python3.10/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning:
#
# The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
